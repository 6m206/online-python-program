# %% [markdown]
# ### LOC , ILOC | GROUPBY

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("netflix_titles.csv")
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data["cast"] = data['cast'].replace(np.nan, "0")

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                     0  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ### Loc

# %%
# data.loc[<row labels>, <column labels>]
data.loc[:,["type"]].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# dtype: int64

# %%
arr = data.loc[1,"cast"].split(", ")
print(arr)
len(arr)
# Out:
# ['Ama Qamata', 'Khosi Ngema', 'Gail Mabalane', 'Thabang Molaba', 'Dillon Windvogel', 'Natasha Thahane', 'Arno Greeff', 'Xolile Tshabalala', 'Getmore Sithole', 'Cindy Mahlangu', 'Ryle De Morny', 'Greteli Fincham', 'Sello Maake Ka-Ncube', 'Odwa Gwanya', 'Mekaila Mathys', 'Sandi Schultz', 'Duane Williams', 'Shamilla Miller', 'Patrick Mofokeng']
# 19

# %%
arr = data.loc[2,"cast"].split(", ")
print(arr)
len(arr)
# Out:
# ['Sami Bouajila', 'Tracy Gotoas', 'Samuel Jouy', 'Nabiha Akkari', 'Sofia Lesaffre', 'Salim Kechiouche', 'Noureddine Farihi', 'Geert Van Rampelberg', 'Bakary Diombera']
# 9

# %%
arr = data.loc[3,"cast"].split(", ")
print(arr)
len(arr)
# Out:
# ['0']
# 1

# %%
arr = data.loc[4,"cast"].split(", ")
print(arr)
len(arr)
# Out:
# ['Mayur More', 'Jitendra Kumar', 'Ranjan Raj', 'Alam Khan', 'Ahsaas Channa', 'Revathi Pillai', 'Urvi Singh', 'Arun Kumar']
# 8

# %%
arr = data.loc[8802,"cast" ].split(", ")
print(arr)
len(arr)
# Out:
# ['Mark Ruffalo', 'Jake Gyllenhaal', 'Robert Downey Jr.', 'Anthony Edwards', 'Brian Cox', 'Elias Koteas', 'Donal Logue', 'John Carroll Lynch', 'Dermot Mulroney', 'Chloë Sevigny']
# 10

# %%
arr = data.loc[8803,"cast"].split(", ")
print(arr)
len(arr)
# Out:
# ['0']
# 1

# %%
arr = data.loc[8804,"cast"].split(", ")
print(arr)
len(arr)
# Out:
# ['Jesse Eisenberg', 'Woody Harrelson', 'Emma Stone', 'Abigail Breslin', 'Amber Heard', 'Bill Murray', 'Derek Graf']
# 7

# %%
arr = data.loc[8805,"cast"].split(", ")
print(arr)
len(arr)
# Out:
# ['Tim Allen', 'Courteney Cox', 'Chevy Chase', 'Kate Mara', 'Ryan Newman', 'Michael Cassidy', 'Spencer Breslin', 'Rip Torn', 'Kevin Zegers']
# 9

# %%
arr = data.loc[8806,"cast"].split(", ")
print(arr)
len(arr)
# Out:
# ['Vicky Kaushal', 'Sarah-Jane Dias', 'Raaghav Chanana', 'Manish Chaudhary', 'Meghna Malik', 'Malkeet Rauni', 'Anita Shabdish', 'Chittaranjan Tripathy']
# 8

# %%
# "num_of_cast"
data["num_of_cast"] = data["cast"]
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                     0  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data.loc[data["show_id"] =="s2", "cast"] = "19"

# %%
data.loc[data["show_id"] =="s2", "num_of_cast"] = "19"

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                     0  United States
# 1                                                    19   South Africa
# ...

# %%
data.loc[data["show_id"] =="s3", "cast"] = "9"
data.loc[data["show_id"] =="s3", "num_of_cast"] = "9"

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                     0  United States
# 1                                                    19   South Africa
# ...

# %%
data.loc[data["show_id"] =="s4", "cast"] = "0"
data.loc[data["show_id"] =="s4", "num_of_cast"] = "0"

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                     0  United States
# 1                                                    19   South Africa
# ...

# %%
data.loc[data["show_id"] =="s8803", "cast"] = "10"
data.loc[data["show_id"] =="s8803", "num_of_cast"] = "10"

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                     0  United States
# 1                                                    19   South Africa
# ...

# %%
data.loc[data["show_id"] =="s8805", "cast"] = "7"
data.loc[data["show_id"] =="s8805", "num_of_cast"] = "7"

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                     0  United States
# 1                                                    19   South Africa
# ...

# %%
data.loc[data["show_id"] =="s8806", "cast"] = "9"
data.loc[data["show_id"] =="s8806", "num_of_cast"] = "9"

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                     0  United States
# 1                                                    19   South Africa
# ...

# %%
data.loc[data["show_id"] =="s8807", "cast"] = "8"
data.loc[data["show_id"] =="s8807", "num_of_cast"] = "8"

# %%
data
# Out:
#      show_id     type                  title         director cast  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson    0
# 1         s2  TV Show          Blood & Water              NaN   19
# 2         s3  TV Show              Ganglands  Julien Leclercq    9
# 3         s4  TV Show  Jailbirds New Orleans              NaN    0
# 4         s5  TV Show           Kota Factory              NaN    8
# ...      ...      ...                    ...              ...  ...
# 8802   s8803    Movie                 Zodiac    David Fincher   10
# 8803   s8804  TV Show            Zombie Dumb              NaN    7
# 8804   s8805    Movie             Zombieland  Ruben Fleischer    7
# 8805   s8806    Movie                   Zoom     Peter Hewitt    9
# 8806   s8807    Movie                 Zubaan      Mozez Singh    8
#
#             country          date_added  release_year rating   duration  \
# 0     United States  September 25, 2021          2020  PG-13     90 min
# ...

# %% [markdown]
# ###  GroupBy

# %%
data.head()
# Out:
#   show_id     type                  title         director cast  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson    0
# 1      s2  TV Show          Blood & Water              NaN   19
# 2      s3  TV Show              Ganglands  Julien Leclercq    9
# 3      s4  TV Show  Jailbirds New Orleans              NaN    0
# 4      s5  TV Show           Kota Factory              NaN    8
#
#          country          date_added  release_year rating   duration  \
# 0  United States  September 25, 2021          2020  PG-13     90 min
# 1   South Africa  September 24, 2021          2021  TV-MA  2 Seasons
# 2            NaN  September 24, 2021          2021  TV-MA   1 Season
# 3            NaN  September 24, 2021          2021  TV-MA   1 Season
# 4          India  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# ...

# %%
data.groupby("type")["show_id"].value_counts()
# Out:
# type     show_id
# Movie    s1         1
#          s10        1
#          s1000      1
#          s1001      1
#          s1002      1
#                    ..
# TV Show  s98        1
#          s989       1
#          s99        1
#          s994       1
#          s998       1
# Name: show_id, Length: 8807, dtype: int64
